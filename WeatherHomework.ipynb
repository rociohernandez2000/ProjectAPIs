# %%
import random
import requests as req
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import openweathermapy as owm
from config import api_key
#To get the current date
import datetime
now = datetime.datetime.now()

# %%
randlong = np.random.uniform(low=-180, high=181, size=2000).tolist()
randlatit = np.random.uniform(low=-90, high=91, size=2000).tolist()

# %%
cities = []

for lat, lon in zip(randlatit, randlong):
    city = citipy.nearest_city(lat, lon)
    if city not in cities:
        cities.append(city.city_name)
    else:
        city = citipy.nearest_city(lat, lon)
        cities.append(city.city_name)

# %%
len(set(cities))
# Out:
# 770

# %%
cities_unique = list(set(cities))

# %%
url = "http://api.openweathermap.org/data/2.5/weather"

params = {'appid': api_key,
          'q': '',
          'units': 'imperial'}

weather_data = {'City': [],
               'Cloudiness': [],
               'Country': [],
               'Date': [],
               'Humidity': [],
               'Lat': [],
               'Lng':[],
               'Max_Temp':[],
               'Wind Speed':[]}

city_count = 1
city_count_final = 501

print('Beginning Retrieval')
print('-----------------------------')

for city in cities_unique:
    try:
    # Get weather data
        params['q'] = city
        response = req.get(url, params=params).json()
    # Get weather params for df for at least 500 cities
        if city_count == city_count_final:
            print('-----------------------------')
            print('Retrieval Complete')
            print('-----------------------------')
            break
        elif city not in weather_data['City']:  
            # Construct weather_data dictionary
            weather_data['City'].append(response['name'])
            weather_data['Cloudiness'].append(response['clouds']['all'])
            weather_data['Country'].append(response['sys']['country'])
            weather_data['Date'].append(response['dt'])
            weather_data['Humidity'].append(response['main']['humidity'])
            weather_data['Lat'].append(response['coord']['lat'])
            weather_data['Lng'].append(response['coord']['lon'])
            weather_data['Max_Temp'].append(response['main']['temp_max'])
            weather_data['Wind Speed'].append(response['wind']['speed'])
            print(f'Processing Record {city_count} of 500 | {city}')
            print(f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={api_key}&q={city.replace(" ", "%20")}')
            city_count += 1
        elif city in weather_data['City']:
            continue
    except KeyError:
        print(f'{city} not found. Skipping...')
# Out:
# Beginning Retrieval
# -----------------------------
# Processing Record 1 of 500 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=erenhot
# Processing Record 2 of 500 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ajdabiya
# Processing Record 3 of 500 | khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=khash
# Processing Record 4 of 500 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=shimoda
# jiddah not found. Skipping...
# Processing Record 5 of 500 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=airai
# Processing Record 6 of 500 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tuatapere
# Processing Record 7 of 500 | masindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=masindi
# Processing Record 8 of 500 | shelbyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=shelbyville
# Processing Record 9 of 500 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=georgetown
# Processing Record 10 of 500 | virtsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=virtsu
# Processing Record 11 of 500 | novokizhinginsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=novokizhinginsk
# Processing Record 12 of 500 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=najran
# Processing Record 13 of 500 | kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kasongo-lunda
# Processing Record 14 of 500 | bure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bure
# Processing Record 15 of 500 | anzio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=anzio
# Processing Record 16 of 500 | muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=muli
# Processing Record 17 of 500 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mareeba
# Processing Record 18 of 500 | hit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hit
# Processing Record 19 of 500 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lorengau
# gormi not found. Skipping...
# Processing Record 20 of 500 | ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ati
# Processing Record 21 of 500 | ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ouallam
# Processing Record 22 of 500 | ravenna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ravenna
# Processing Record 23 of 500 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=goderich
# Processing Record 24 of 500 | homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=homer
# Processing Record 25 of 500 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vila%20velha
# Processing Record 26 of 500 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=fairbanks
# Processing Record 27 of 500 | hyeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hyeres
# tawkar not found. Skipping...
# Processing Record 28 of 500 | cabot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cabot
# Processing Record 29 of 500 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=opuwo
# barentsburg not found. Skipping...
# Processing Record 30 of 500 | olavarria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=olavarria
# Processing Record 31 of 500 | molchanovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=molchanovo
# Processing Record 32 of 500 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sioux%20lookout
# Processing Record 33 of 500 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sola
# Processing Record 34 of 500 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vanimo
# saleaula not found. Skipping...
# Processing Record 35 of 500 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=boende
# Processing Record 36 of 500 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20rafael
# Processing Record 37 of 500 | bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bud
# Processing Record 38 of 500 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=xining
# Processing Record 39 of 500 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mogadishu
# Processing Record 40 of 500 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=evensk
# Processing Record 41 of 500 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=maragogi
# Processing Record 42 of 500 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pangnirtung
# Processing Record 43 of 500 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ternate
# Processing Record 44 of 500 | rumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=rumford
# Processing Record 45 of 500 | ponnani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ponnani
# Processing Record 46 of 500 | yzeure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yzeure
# Processing Record 47 of 500 | mandalay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mandalay
# amderma not found. Skipping...
# Processing Record 48 of 500 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=axim
# Processing Record 49 of 500 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=zhigansk
# Processing Record 50 of 500 | jaena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=jaena
# Processing Record 51 of 500 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=husavik
# Processing Record 52 of 500 | karakol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=karakol
# Processing Record 53 of 500 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bathsheba
# Processing Record 54 of 500 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=port%20hedland
# Processing Record 55 of 500 | nevers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nevers
# Processing Record 56 of 500 | wloclawek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wloclawek
# Processing Record 57 of 500 | stony plain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=stony%20plain
# Processing Record 58 of 500 | mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mokhsogollokh
# Processing Record 59 of 500 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=umm%20lajj
# Processing Record 60 of 500 | rebrikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=rebrikha
# Processing Record 61 of 500 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=avarua
# Processing Record 62 of 500 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kalmunai
# Processing Record 63 of 500 | honggang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=honggang
# Processing Record 64 of 500 | la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=la%20palma
# karkaralinsk not found. Skipping...
# Processing Record 65 of 500 | kremenki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kremenki
# Processing Record 66 of 500 | abonnema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=abonnema
# Processing Record 67 of 500 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=souillac
# Processing Record 68 of 500 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nanortalik
# Processing Record 69 of 500 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=saint%20george
# colacling not found. Skipping...
# Processing Record 70 of 500 | witu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=witu
# Processing Record 71 of 500 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kidal
# Processing Record 72 of 500 | oyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=oyama
# dolbeau not found. Skipping...
# Processing Record 73 of 500 | bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bosaso
# Processing Record 74 of 500 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20cristobal
# Processing Record 75 of 500 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ahipara
# Processing Record 76 of 500 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alta%20floresta
# Processing Record 77 of 500 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lavrentiya
# tsihombe not found. Skipping...
# Processing Record 78 of 500 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=basco
# Processing Record 79 of 500 | tinaquillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tinaquillo
# Processing Record 80 of 500 | meybod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=meybod
# Processing Record 81 of 500 | mwense
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mwense
# Processing Record 82 of 500 | kurayoshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kurayoshi
# tambura not found. Skipping...
# Processing Record 83 of 500 | aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=aguimes
# Processing Record 84 of 500 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20vicente
# Processing Record 85 of 500 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mumford
# falaleu not found. Skipping...
# Processing Record 86 of 500 | tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tefe
# Processing Record 87 of 500 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=altay
# Processing Record 88 of 500 | austin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=austin
# Processing Record 89 of 500 | wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wuwei
# Processing Record 90 of 500 | marakkanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=marakkanam
# Processing Record 91 of 500 | wuning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wuning
# ondorhaan not found. Skipping...
# Processing Record 92 of 500 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=marsh%20harbour
# toliary not found. Skipping...
# Processing Record 93 of 500 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bredasdorp
# Processing Record 94 of 500 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mandalgovi
# Processing Record 95 of 500 | kita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kita
# Processing Record 96 of 500 | voznesenye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=voznesenye
# paradwip not found. Skipping...
# Processing Record 97 of 500 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=zeya
# Processing Record 98 of 500 | balaguer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=balaguer
# Processing Record 99 of 500 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ancud
# waspan not found. Skipping...
# Processing Record 100 of 500 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=buchanan
# Processing Record 101 of 500 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mackay
# Processing Record 102 of 500 | sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sterling
# Processing Record 103 of 500 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=matagami
# Processing Record 104 of 500 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kaitangata
# Processing Record 105 of 500 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=luena
# Processing Record 106 of 500 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kodiak
# Processing Record 107 of 500 | alvarado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alvarado
# Processing Record 108 of 500 | huescar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=huescar
# Processing Record 109 of 500 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=usinsk
# Processing Record 110 of 500 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=salinopolis
# Processing Record 111 of 500 | virbhadra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=virbhadra
# Processing Record 112 of 500 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alofi
# Processing Record 113 of 500 | hede
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hede
# Processing Record 114 of 500 | mtwara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mtwara
# Processing Record 115 of 500 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=matara
# Processing Record 116 of 500 | potosi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=potosi
# Processing Record 117 of 500 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=touros
# Processing Record 118 of 500 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=qaqortoq
# Processing Record 119 of 500 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hay%20river
# ambodifototra not found. Skipping...
# Processing Record 120 of 500 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pontianak
# Processing Record 121 of 500 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=aklavik
# Processing Record 122 of 500 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ilhabela
# Processing Record 123 of 500 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=faanui
# Processing Record 124 of 500 | luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=luau
# pingzhuang not found. Skipping...
# Processing Record 125 of 500 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wanning
# Processing Record 126 of 500 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=port%20alfred
# Processing Record 127 of 500 | hastings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hastings
# Processing Record 128 of 500 | lixourion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lixourion
# sorvag not found. Skipping...
# Processing Record 129 of 500 | parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=parrita
# Processing Record 130 of 500 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mataura
# Processing Record 131 of 500 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=oranjemund
# Processing Record 132 of 500 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=katobu
# Processing Record 133 of 500 | azle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=azle
# Processing Record 134 of 500 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kalabo
# Processing Record 135 of 500 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=saint-augustin
# Processing Record 136 of 500 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=chokurdakh
# Processing Record 137 of 500 | ziezmariai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ziezmariai
# Processing Record 138 of 500 | kaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kaka
# Processing Record 139 of 500 | hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hun
# Processing Record 140 of 500 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=arraial%20do%20cabo
# Processing Record 141 of 500 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=eureka
# Processing Record 142 of 500 | tamala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tamala
# Processing Record 143 of 500 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kahului
# linshu not found. Skipping...
# Processing Record 144 of 500 | siquijor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=siquijor
# Processing Record 145 of 500 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=trincomalee
# Processing Record 146 of 500 | caloundra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=caloundra
# Processing Record 147 of 500 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bluff
# Processing Record 148 of 500 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mount%20gambier
# Processing Record 149 of 500 | vozhega
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vozhega
# Processing Record 150 of 500 | itamaraca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=itamaraca
# Processing Record 151 of 500 | morro bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=morro%20bay
# Processing Record 152 of 500 | eusebio ayala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=eusebio%20ayala
# Processing Record 153 of 500 | tagusao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tagusao
# Processing Record 154 of 500 | tolaga bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tolaga%20bay
# Processing Record 155 of 500 | primo tapia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=primo%20tapia
# Processing Record 156 of 500 | samarinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=samarinda
# Processing Record 157 of 500 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hobyo
# Processing Record 158 of 500 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=barcelos
# Processing Record 159 of 500 | japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=japura
# Processing Record 160 of 500 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=coquimbo
# ust-kamchatsk not found. Skipping...
# Processing Record 161 of 500 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=constitucion
# Processing Record 162 of 500 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pochutla
# Processing Record 163 of 500 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ketchikan
# bokspits not found. Skipping...
# Processing Record 164 of 500 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pevek
# Processing Record 165 of 500 | sheridan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sheridan
# Processing Record 166 of 500 | alcudia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alcudia
# Processing Record 167 of 500 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=padang
# Processing Record 168 of 500 | ler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ler
# Processing Record 169 of 500 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ca%20mau
# Processing Record 170 of 500 | mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mao
# dinsor not found. Skipping...
# Processing Record 171 of 500 | bulolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bulolo
# Processing Record 172 of 500 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=olinda
# Processing Record 173 of 500 | phatthalung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=phatthalung
# Processing Record 174 of 500 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=belaya%20gora
# Processing Record 175 of 500 | kodinar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kodinar
# Processing Record 176 of 500 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=zhezkazgan
# Processing Record 177 of 500 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vrangel
# Processing Record 178 of 500 | osa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=osa
# Processing Record 179 of 500 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=longyearbyen
# Processing Record 180 of 500 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=rio%20gallegos
# Processing Record 181 of 500 | ostashkov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ostashkov
# Processing Record 182 of 500 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=gamba
# saryshagan not found. Skipping...
# Processing Record 183 of 500 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=moose%20factory
# Processing Record 184 of 500 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=namatanai
# Processing Record 185 of 500 | sao joaquim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sao%20joaquim
# tabiauea not found. Skipping...
# Processing Record 186 of 500 | macheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=macheng
# Processing Record 187 of 500 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yeppoon
# Processing Record 188 of 500 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=saldanha
# Processing Record 189 of 500 | shuangyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=shuangyang
# Processing Record 190 of 500 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nome
# Processing Record 191 of 500 | bauska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bauska
# Processing Record 192 of 500 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mount%20isa
# Processing Record 193 of 500 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=thunder%20bay
# Processing Record 194 of 500 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ngunguru
# Processing Record 195 of 500 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pangody
# Processing Record 196 of 500 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=svetlogorsk
# abu jubayhah not found. Skipping...
# Processing Record 197 of 500 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hasaki
# Processing Record 198 of 500 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tasiilaq
# Processing Record 199 of 500 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nouadhibou
# Processing Record 200 of 500 | kagoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kagoro
# Processing Record 201 of 500 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lebu
# Processing Record 202 of 500 | adamovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=adamovka
# sentyabrskiy not found. Skipping...
# Processing Record 203 of 500 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yar-sale
# Processing Record 204 of 500 | speedway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=speedway
# Processing Record 205 of 500 | sonoita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sonoita
# falealupo not found. Skipping...
# Processing Record 206 of 500 | tayu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tayu
# Processing Record 207 of 500 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vardo
# Processing Record 208 of 500 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vila%20franca%20do%20campo
# Processing Record 209 of 500 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sorland
# Processing Record 210 of 500 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vaini
# Processing Record 211 of 500 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=luderitz
# Processing Record 212 of 500 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=port%20macquarie
# palabuhanratu not found. Skipping...
# Processing Record 213 of 500 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cockburn%20town
# Processing Record 214 of 500 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lompoc
# Processing Record 215 of 500 | kaohsiung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kaohsiung
# Processing Record 216 of 500 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=buala
# hendijan not found. Skipping...
# mys shmidta not found. Skipping...
# phan rang not found. Skipping...
# Processing Record 217 of 500 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=shimanovsk
# Processing Record 218 of 500 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=katsuura
# Processing Record 219 of 500 | smirnykh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=smirnykh
# Processing Record 220 of 500 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=virginia%20beach
# Processing Record 221 of 500 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=antofagasta
# Processing Record 222 of 500 | pirapemas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pirapemas
# Processing Record 223 of 500 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=veraval
# Processing Record 224 of 500 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=moron
# Processing Record 225 of 500 | abatskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=abatskoye
# Processing Record 226 of 500 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dikson
# Processing Record 227 of 500 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=talnakh
# Processing Record 228 of 500 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lata
# Processing Record 229 of 500 | linhares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=linhares
# tumannyy not found. Skipping...
# armacao dos buzios not found. Skipping...
# Processing Record 230 of 500 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=makakilo%20city
# Processing Record 231 of 500 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cidreira
# Processing Record 232 of 500 | sabla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sabla
# Processing Record 233 of 500 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tarko-sale
# Processing Record 234 of 500 | umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=umba
# Processing Record 235 of 500 | bacoor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bacoor
# waw not found. Skipping...
# Processing Record 236 of 500 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nizhniy%20kuranakh
# vaitupu not found. Skipping...
# Processing Record 237 of 500 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=verkhoyansk
# Processing Record 238 of 500 | palmas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=palmas
# Processing Record 239 of 500 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lazaro%20cardenas
# Processing Record 240 of 500 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=walvis%20bay
# Processing Record 241 of 500 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=waddan
# Processing Record 242 of 500 | iwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=iwaki
# Processing Record 243 of 500 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=trinidad
# Processing Record 244 of 500 | kyzyl-suu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kyzyl-suu
# Processing Record 245 of 500 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=abu%20kamal
# Processing Record 246 of 500 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=aykhal
# Processing Record 247 of 500 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=khasan
# Processing Record 248 of 500 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=buraydah
# Processing Record 249 of 500 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=udachnyy
# Processing Record 250 of 500 | kosino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kosino
# Processing Record 251 of 500 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vestmannaeyjar
# Processing Record 252 of 500 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yellowknife
# Processing Record 253 of 500 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alice%20springs
# Processing Record 254 of 500 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=garowe
# Processing Record 255 of 500 | stykkisholmur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=stykkisholmur
# Processing Record 256 of 500 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=seoul
# Processing Record 257 of 500 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bambanglipuro
# Processing Record 258 of 500 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=puerto%20ayora
# Processing Record 259 of 500 | kalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kalia
# Processing Record 260 of 500 | berezna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=berezna
# Processing Record 261 of 500 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=palmer
# Processing Record 262 of 500 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=fortuna
# Processing Record 263 of 500 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=havre-saint-pierre
# Processing Record 264 of 500 | kontagora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kontagora
# Processing Record 265 of 500 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=paamiut
# Processing Record 266 of 500 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=flinders
# Processing Record 267 of 500 | marevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=marevo
# abomsa not found. Skipping...
# Processing Record 268 of 500 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cape%20town
# Processing Record 269 of 500 | sayat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sayat
# Processing Record 270 of 500 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=east%20london
# Processing Record 271 of 500 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=narsaq
# Processing Record 272 of 500 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kruisfontein
# Processing Record 273 of 500 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ribeira%20grande
# Processing Record 274 of 500 | dobryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dobryanka
# Processing Record 275 of 500 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=richards%20bay
# Processing Record 276 of 500 | angoche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=angoche
# Processing Record 277 of 500 | gusau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=gusau
# zhanatas not found. Skipping...
# Processing Record 278 of 500 | verkhniy uslon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=verkhniy%20uslon
# Processing Record 279 of 500 | gravelbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=gravelbourg
# Processing Record 280 of 500 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=port%20moresby
# Processing Record 281 of 500 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20quintin
# Processing Record 282 of 500 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=leningradskiy
# Processing Record 283 of 500 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=grand%20gaube
# Processing Record 284 of 500 | yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yokadouma
# Processing Record 285 of 500 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20patricio
# Processing Record 286 of 500 | mazatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mazatlan
# Processing Record 287 of 500 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=lulea
# Processing Record 288 of 500 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sechura
# Processing Record 289 of 500 | salantai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=salantai
# Processing Record 290 of 500 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nemuro
# Processing Record 291 of 500 | sawtell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sawtell
# Processing Record 292 of 500 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nicoya
# Processing Record 293 of 500 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=puerto%20baquerizo%20moreno
# Processing Record 294 of 500 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=abu%20dhabi
# Processing Record 295 of 500 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=inuvik
# Processing Record 296 of 500 | shizunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=shizunai
# Processing Record 297 of 500 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=praia%20da%20vitoria
# Processing Record 298 of 500 | juquia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=juquia
# Processing Record 299 of 500 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kavieng
# Processing Record 300 of 500 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=biak
# Processing Record 301 of 500 | karpogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=karpogory
# Processing Record 302 of 500 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=labuhan
# Processing Record 303 of 500 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cabo%20san%20lucas
# Processing Record 304 of 500 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mapiripan
# Processing Record 305 of 500 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=geraldton
# Processing Record 306 of 500 | bam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bam
# Processing Record 307 of 500 | ingham
# ...
# tsienyane not found. Skipping...
# Processing Record 400 of 500 | san miguel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20miguel
# Processing Record 401 of 500 | macau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=macau
# Processing Record 402 of 500 | boyabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=boyabat
# Processing Record 403 of 500 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=los%20llanos%20de%20aridane
# Processing Record 404 of 500 | hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hohhot
# Processing Record 405 of 500 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=mayo
# Processing Record 406 of 500 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=fort%20nelson
# Processing Record 407 of 500 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=miri
# Processing Record 408 of 500 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dwarka
# Processing Record 409 of 500 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=castro
# Processing Record 410 of 500 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ambon
# Processing Record 411 of 500 | dabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dabat
# Processing Record 412 of 500 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=igarka
# Processing Record 413 of 500 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tabou
# Processing Record 414 of 500 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=qaanaaq
# Processing Record 415 of 500 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=arlit
# Processing Record 416 of 500 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=anadyr
# Processing Record 417 of 500 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=grand-santi
# Processing Record 418 of 500 | diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=diffa
# Processing Record 419 of 500 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=klaksvik
# Processing Record 420 of 500 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=half%20moon%20bay
# Processing Record 421 of 500 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=port%20lincoln
# Processing Record 422 of 500 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ugoofaaru
# Processing Record 423 of 500 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=biltine
# Processing Record 424 of 500 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=northam
# Processing Record 425 of 500 | cayhagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cayhagan
# Processing Record 426 of 500 | gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=gwadar
# Processing Record 427 of 500 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=santa%20cruz
# Processing Record 428 of 500 | bintulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bintulu
# canaries not found. Skipping...
# Processing Record 429 of 500 | wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wajima
# Processing Record 430 of 500 | cheremshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=cheremshan
# Processing Record 431 of 500 | langsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=langsa
# Processing Record 432 of 500 | novikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=novikovo
# Processing Record 433 of 500 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=portland
# Processing Record 434 of 500 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pisco
# Processing Record 435 of 500 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=preobrazheniye
# Processing Record 436 of 500 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=tomatlan
# urdzhar not found. Skipping...
# Processing Record 437 of 500 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pacific%20grove
# Processing Record 438 of 500 | san esteban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=san%20esteban
# Processing Record 439 of 500 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sangar
# Processing Record 440 of 500 | perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=perth
# Processing Record 441 of 500 | narrabri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=narrabri
# Processing Record 442 of 500 | popondetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=popondetta
# Processing Record 443 of 500 | morwell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=morwell
# Processing Record 444 of 500 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=roma
# Processing Record 445 of 500 | juybar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=juybar
# Processing Record 446 of 500 | formosa do rio preto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=formosa%20do%20rio%20preto
# Processing Record 447 of 500 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=namibe
# Processing Record 448 of 500 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=jiuquan
# Processing Record 449 of 500 | yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yelizovo
# Processing Record 450 of 500 | forestville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=forestville
# Processing Record 451 of 500 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=clyde%20river
# Processing Record 452 of 500 | bhatkal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bhatkal
# Processing Record 453 of 500 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=jamestown
# Processing Record 454 of 500 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=srandakan
# Processing Record 455 of 500 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=broome
# chaa-khol not found. Skipping...
# Processing Record 456 of 500 | bom jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bom%20jardim
# Processing Record 457 of 500 | parscov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=parscov
# Processing Record 458 of 500 | ashqelon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ashqelon
# olafsvik not found. Skipping...
# Processing Record 459 of 500 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=atuona
# Processing Record 460 of 500 | wuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=wuan
# Processing Record 461 of 500 | goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=goma
# Processing Record 462 of 500 | bikaner
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=bikaner
# lolua not found. Skipping...
# Processing Record 463 of 500 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=komsomolskiy
# Processing Record 464 of 500 | dumai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dumai
# Processing Record 465 of 500 | alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=alexandria
# Processing Record 466 of 500 | rio verde de mato grosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=rio%20verde%20de%20mato%20grosso
# Processing Record 467 of 500 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=isangel
# Processing Record 468 of 500 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=nanakuli
# Processing Record 469 of 500 | sala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=sala
# Processing Record 470 of 500 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=faya
# Processing Record 471 of 500 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=jumla
# Processing Record 472 of 500 | pyay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=pyay
# Processing Record 473 of 500 | vung tau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=vung%20tau
# korla not found. Skipping...
# Processing Record 474 of 500 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=muyezerskiy
# Processing Record 475 of 500 | ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ormara
# Processing Record 476 of 500 | kassala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kassala
# Processing Record 477 of 500 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=plettenberg%20bay
# Processing Record 478 of 500 | ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ilebo
# Processing Record 479 of 500 | naumburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=naumburg
# Processing Record 480 of 500 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=hithadhoo
# Processing Record 481 of 500 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=puerto%20escondido
# Processing Record 482 of 500 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=beisfjord
# Processing Record 483 of 500 | brandfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=brandfort
# Processing Record 484 of 500 | kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kailua
# Processing Record 485 of 500 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=rikitea
# belushya guba not found. Skipping...
# Processing Record 486 of 500 | yen bai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=yen%20bai
# nizhneyansk not found. Skipping...
# Processing Record 487 of 500 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=kulhudhuffushi
# Processing Record 488 of 500 | magistralnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=magistralnyy
# Processing Record 489 of 500 | andradina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=andradina
# la gaulette not found. Skipping...
# karaul not found. Skipping...
# Processing Record 490 of 500 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=caravelas
# Processing Record 491 of 500 | fivizzano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=fivizzano
# Processing Record 492 of 500 | payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=payo
# Processing Record 493 of 500 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=acajutla
# Processing Record 494 of 500 | dire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=dire
# Processing Record 495 of 500 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ballina
# Processing Record 496 of 500 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=thompson
# gangotri not found. Skipping...
# Processing Record 497 of 500 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=ponta%20delgada
# asau not found. Skipping...
# Processing Record 498 of 500 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=henties%20bay
# Processing Record 499 of 500 | erdenet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=erdenet
# we not found. Skipping...
# Processing Record 500 of 500 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8d8c016064e4e22cf7cc057455e53979&q=gravdal
# -----------------------------
# Retrieval Complete
# -----------------------------

# %%
weather_df = pd.DataFrame(weather_data)

# Check that there are at least 500 unique cities obtained from API requests
len(weather_df['City'].unique())
# Out:
# 500

# %%
weather_df.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Erenhot           0      CN  1549846833        70  43.65  111.97
# 1  Ajdabiya           0      LY  1549846837        83  30.75   20.22
# 2     Khash          36      IR  1549846837        90  28.22   61.21
# 3   Shimoda          75      JP  1549843200        87  34.70  138.93
# 4     Airai          36      TL  1549846838        87  -8.93  125.41
#
#    Max_Temp  Wind Speed
# 0    -17.59        2.91
# 1     37.99        2.80
# 2     40.65        3.69
# 3     42.80       18.34
# 4     75.07        2.01

# %%
plt.scatter(weather_df['Lat'], weather_df['Max_Temp'],
           marker = 'o', facecolors='blue', 
           edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (12/02/17)')
plt.grid(True)
plt.savefig('CityLatvsMaxTemp.png')
plt.show()

# %%
plt.scatter(weather_df['Lat'], weather_df['Humidity'],
           marker = 'o', facecolors='blue', 
           edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (12/02/17)')
plt.xlim(-80, 100)
plt.ylim(-20, 120)
plt.grid(True)
plt.savefig('CityLatvsHumidity.png')
plt.show()

# %%
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'],
           marker = 'o', facecolors='blue', 
           edgecolors='black', alpha=0.8)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (12/02/17)')
plt.xlim(-80, 100)
plt.ylim(-20, 120)
plt.grid(True)
plt.savefig('CityLatvsCloudiness.png')
plt.show()

# %%
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'],
           marker = 'o', facecolors='blue', 
           edgecolors='black', alpha=0.8)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (12/02/17)')
plt.xlim(-80, 100)
plt.ylim(-5, 40)
plt.grid(True)
plt.savefig('CityLatvsWindSpeed.png')
plt.show()

# %%
weather_df.to_csv('MG_weather_df.csv', index=False)
